# %% [markdown]
# <a href="https://colab.research.google.com/github/18K41A0524/AI/blob/master/18K41A0524_AIp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
 
import pandas as pd
d=pd.read_csv("//content/drive/My Drive/mobile_cleaned-1549119762886_-452616671.csv")
pd.set_option("display.max_rows",None,"display.max_columns",None)
d
# Out:
#      sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0           0        12        55   155.0          250.0                 1.30
# 1           0         1        55   132.0          300.0                 1.30
# 2           0         9        55   142.0          329.0                 1.50
# 3           0         8        55   152.0          385.0                 1.30
# 4           1         1        55   234.0          385.0                 1.30
# 5           0        14        55   179.0          280.0                 1.30
# 6           1         1        56   124.0          230.0                 1.30
# 7           0         8        41   154.0          182.0                 1.00
# 8           1         8        41   214.0          182.0                 1.00
# 9           0         1        55   155.0          435.0                 1.30
# 10          0         1        55   169.0            NaN                 1.30
# ...

# %%
 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 
import matplotlib.pyplot as plt
p=list(d["price"])
l=list(d.columns)
for n in l :
  c=list(d[n])
plt.xlabel(n)
plt.ylabel("price")
plt.plot(c,p,label=n)
plt.scatter(c,p)
plt.legend()
plt.show()

# %%
 
import numpy as np
p=[[1,0],[0,1]]
q=[[1,2],[3,4]]
np.outer(p,q)
# Out:
# array([[1, 2, 3, 4],
#        [0, 0, 0, 0],
#        [0, 0, 0, 0],
#        [1, 2, 3, 4]])

# %%
 
import numpy as np
matrix = np.array([[1, 2], [3, 4]])
print("Original matrix: ")
print(matrix)
print("Condition number of the said matrix: ")
result = np.linalg.cond(matrix)
print(result)
# Out:
# Original matrix:
# [[1 2]
#  [3 4]]
# Condition number of the said matrix:
# 14.933034373659268

# %%
 
d=np.array([[10,8,5],[4,4,9],[3,0,5]])
print("matrix=\n",d)
p=np.trace(d)
print("trace=",p)
# Out:
# matrix=
#  [[10  8  5]
#  [ 4  4  9]
#  [ 3  0  5]]
# trace= 19
